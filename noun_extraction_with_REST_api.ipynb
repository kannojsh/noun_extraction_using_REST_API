# %% [markdown]
# # Noun Extraction with REST API

# %%
# Constants
NO_OF_PAGES =2
FILE_NAME = r'Software_requirements_specification_analysis_using_natural_language_processing_technique.pdf'

# Convert corpus from 2D to 1D
def convert2Dto1DList(myList):
#     import itertools
#     return list(itertools.chain.from_iterable(corpus))
    return [n for one_dim in myList for n in one_dim]

# Remove duplicate values from the list
def removeDuplicates(myList):
    return list(dict.fromkeys(myList))

# Extract the nouns from text document
def extractNounsFromDocument(document): 
    total_nouns = [str(word) for word in document if word.pos_=='NOUN']
    return removeDuplicates(total_nouns)

# %%
# loading the english model
import spacy
nlp = spacy.load('en_core_web_sm',disable=['ner','textcat'])
data = open(FILE_NAME, 'rb')

# %%
#fetch the text from the pdf file
import PyPDF2
pdfReader = PyPDF2.PdfFileReader(data)
pageNumber = pdfReader.getPage(NO_OF_PAGES)
text = pageNumber.extractText()

#create spacy
text = nlp(text)
text = str(text)

# %%
# Cleaning the texts
import re
import nltk
# nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

ps = PorterStemmer()
wordnet=WordNetLemmatizer()
sentences = nltk.sent_tokenize(text)
corpus = []
for i in range(len(sentences)):
    review = re.sub('[^a-zA-Z]', ' ', sentences[i])
    review = review.lower()
    review = review.split()
    review = [wordnet.lemmatize(word) for word in review if not word in set(stopwords.words('english'))]
    corpus.append(review)
#print(corpus)

# %%
corpus = convert2Dto1DList(corpus)
#print(corpus)

# %%
#print(corpus)
total_nouns = extractNounsFromDocument(nlp(",".join(corpus)))
print(total_nouns)
# Out:
# ['system', 'method', 'scenario', 'structure', 'novice', 'defines', 'requirement', 'form', 'event', 'state', 'action', 'kind', 'part', 'software', 'way', 'case', 'incident', 'cause', 'activation', 'activity', 'agent', 'change', 'entity', 'object', 'resource', 'condition', 'phase', 'lifecycle', 'pre', 'execution', 'post', 'type', 'specification', 'format', 'describes', 'example', 'table', 'elector', 'election', 'pda', 'analyze', 'flow', 'show', 'home', 'screen', 'po', 'enters', 'name', 'search', 'time', 'list', 'scre', 'butt', 'rule', 'need', 'bracket', 'interface', 'button', 'reason', 'element', 'translation', 'process', 'scope', 'paper', 'version', 'order', 'ii', 'conflict', 'feasibility', 'result', 'refining', 'discussion', 'language', 'formalspecification', 'set', 'reed', 'transformedin', 'extension', 'work', 'study', 'facea', 'couple', 'limitation', 'methodas', 'translate', 'context', 'concern', 'engineering', 'capability', 'model', 'lack', 'recommendation', 'future', 'counterpart
# ...

# %%
total_nouns
# Out:
# ['system',
#  'method',
#  'scenario',
#  'structure',
#  'novice',
#  'defines',
#  'requirement',
#  'form',
#  'event',
#  'state',
#  'action',
#  'kind',
#  'part',
#  'software',
#  'way',
#  'case',
#  'incident',
#  'cause',
#  'activation',
#  'activity',
#  'agent',
#  'change',
#  'entity',
#  'object',
#  'resource',
#  'condition',
#  'phase',
#  'lifecycle',
#  'pre',
#  'execution',
#  'post',
#  'type',
#  'specification',
#  'format',
#  'describes',
#  'example',
#  'table',
#  'elector',
#  'election',
#  'pda',
#  'analyze',
#  'flow',
#  'show',
#  'home',
#  'screen',
#  'po',
#  'enters',
#  'name',
#  'search',
#  'time',
#  'list',
#  'scre',
#  'butt',
#  'rule',
#  'need',
#  'bracket',
#  'interface',
#  'button',
#  'reason',
#  'element',
#  'translation',
#  'process',
#  'scope',
#  'paper',
#  'version',
#  'order',
#  'ii',
#  'conflict',
#  'feasibility',
#  'result',
#  'refining',
#  'discussion',
#  'language',
#  'formalspecification',
# ...
